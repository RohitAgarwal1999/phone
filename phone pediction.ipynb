# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
phone = pd.read_csv('amazon_phone_dataset.csv', encoding = "ISO-8859-1")

# %%
phone.head()
# Out:
#                                         Product_name  by_info  \
# 0            Samsung Galaxy M10 (Ocean Blue, 3+32GB)  Samsung
# 1         Redmi 6 Pro (Black, 4GB RAM, 64GB Storage)       Mi
# 2  Coolpad Cool 3 Plus (Ocean Blue, 2GB RAM, 16GB...  Coolpad
# 3         Redmi 6 Pro (Black, 3GB RAM, 32GB Storage)       Mi
# 4                                  Nokia 105 (Black)    Nokia
#
#                                          Product_url  \
# 0  https://www.amazon.in/Samsung-Galaxy-Ocean-Blu...
# 1  https://www.amazon.in/Redmi-Pro-Black-64GB-Sto...
# 2  https://www.amazon.in/Coolpad-Cool-Plus-Ocean-...
# 3  https://www.amazon.in/Redmi-Pro-Black-32GB-Sto...
# 4  https://www.amazon.in/Nokia-105-Black/dp/B0745...
#
#                                          Product_img  Product_price  \
# 0  https://images-na.ssl-images-amazon.com/images...  â¹Â 7,990.00
# 1  https://images-na.ssl-images-amazon.com/images...            NaN
# ...

# %%
phone.tail().T
# Out:
#                                                             9565  \
# Product_name   Ktrack Metal and Plastic Open Pry Screwdriver ...
# by_info                                                   Ktrack
# Product_url    https://www.amazon.in/Ktrack-Plastic-Screwdriv...
# Product_img                                                  NaN
# Product_price                                                NaN
# rating                                        2.9 out of 5 stars
# total_review                                 71 customer reviews
# ans_ask                                    60 answered questions
# prod_des       Product: Tool Metal and plastic. 8 in 1 tools ...
# feature        Material: Metal and Plastic8 In 1 tools consis...
# cust_review    Really very helpful tools for laptop pc and mo...
#
#                                                             9566  \
# Product_name   Samsung S-View Flip Cover for Samsung Galaxy S...
# ...

# %%
# Profession of BB Season Winners
phone.loc[phone.by_info=='Mi','rating'].value_counts().head()
# Out:
# 4.0 out of 5 stars    14
# 4.1 out of 5 stars    12
# 3.8 out of 5 stars     9
# 4.2 out of 5 stars     7
# 3.7 out of 5 stars     4
# Name: rating, dtype: int64

# %%
# Profession of BB Season Winners
phone.loc[phone.by_info=='Mi'].head()
# Out:
#                                   Product_name by_info  \
# 1   Redmi 6 Pro (Black, 4GB RAM, 64GB Storage)      Mi
# 3   Redmi 6 Pro (Black, 3GB RAM, 32GB Storage)      Mi
# 9           Mi A2 (Red, 4GB RAM, 64GB Storage)      Mi
# 18       Redmi 6 (Gold, 3GB RAM, 64GB Storage)      Mi
# 24       Redmi 6 (Blue, 3GB RAM, 64GB Storage)      Mi
#
#                                           Product_url  \
# 1   https://www.amazon.in/Redmi-Pro-Black-64GB-Sto...
# 3   https://www.amazon.in/Redmi-Pro-Black-32GB-Sto...
# 9   https://www.amazon.in/Mi-A2-Red-64GB-Storage/d...
# 18  https://www.amazon.in/Redmi-Gold-3GB-64GB-Stor...
# 24  https://www.amazon.in/Redmi-Blue-3GB-64GB-Stor...
#
#                                           Product_img Product_price  \
# 1   https://images-na.ssl-images-amazon.com/images...           NaN
# 3   https://images-na.ssl-images-amazon.com/images...           NaN
# 9   https://images-na.ssl-images-amazon.com/images...           NaN
# ...

# %%
# Profession of BB Season Winners
phone.loc[phone.by_info=='Mi','feature']
# Out:
# 1       12MP+5MP dual rear camera | 5MP front facing c...
# 3       12MP+5MP dual rear camera | 5MP front facing c...
# 9       12MP+20MP dual rear camera and 20MP front faci...
# 18      12MP+5MP dual rear camera with LED selfie flas...
# 24      12MP+5MP dual rear camera with LED selfie flas...
# 32      12MP+5MP dual rear camera with LED selfie flas...
# 34      13MP rear camera | 5MP front camera ; Slender ...
# 36      12MP+5MP dual rear camera | 5MP front facing c...
# 46      12MP+5MP dual rear camera and 5MP front facing...
# 47      12MP+5MP dual rear camera with LED selfie flas...
# 60      12MP+20MP dual rear camera and 20MP front faci...
# 63      13MP rear camera | 5MP front camera13.8 centim...
# 69      12MP+5MP dual rear camera with LED selfie flas...
# 73      12MP + 5 MP AI dual camera;5MP front cameraDis...
# 77      12MP+5MP dual rear camera | 5MP front facing c...
# 81      12MP+20MP dual rear camera and 20MP front faci...
# ...

# %%
a=phone.loc[phone.by_info=='Mi','rating']
for var, in a:
    print(var[0:4])
# Out:
# 4.1
# 4.1
# 3.8
# 4.0
# 4.0
# 4.0
# 4.2
# 4.1
# 4.1
# 4.0
# 3.8
# 4.2
# 4.0
# 4.1
# 4.1
# 3.8
# 3.8
# 3.8
# 4.1
# 4.3
# 4.1
# 3.8
# 4.3
# 3.8
# 4.2
# 4.0
# 4.2
# 3.4
# 3.4
# 4.0
# 3.7
# 3.7
# 3.8
# 4.0
# 3.7
# 3.7
# 4.1
# 3.8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-a102d2fee935> in <module>()
#       1 a=phone.loc[phone.by_info=='Mi','rating']
#       2 for var in a:
# ----> 3     print(var[0:4])
#
# TypeError: 'float' object is not subscriptable
